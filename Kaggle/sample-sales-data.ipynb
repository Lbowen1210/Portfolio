# %% [markdown]
# # import libaries and data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# import our dataset

path = '/kaggle/input/sample-sales-data/sales_data_sample.csv'

sales_data = pd.read_csv(path, encoding='latin')
 
sales_data
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %% [markdown]
# # Check data

# %%
#sales_data.columns()

# %%
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   object
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   object
# ...

# %%
sales_data.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER  \
# count   2823.000000      2823.000000  2823.000000      2823.000000
# mean   10258.725115        35.092809    83.658544         6.466171
# std       92.085478         9.741443    20.174277         4.225841
# min    10100.000000         6.000000    26.880000         1.000000
# 25%    10180.000000        27.000000    68.860000         3.000000
# 50%    10262.000000        35.000000    95.700000         6.000000
# 75%    10333.500000        43.000000   100.000000         9.000000
# max    10425.000000        97.000000   100.000000        18.000000
#
#               SALES       QTR_ID     MONTH_ID     YEAR_ID         MSRP
# count   2823.000000  2823.000000  2823.000000  2823.00000  2823.000000
# mean    3553.889072     2.717676     7.092455  2003.81509   100.715551
# std     1841.865106     1.203878     3.656633     0.69967    40.187912
# min      482.130000     1.000000     1.000000  2003.00000    33.000000
# ...

# %%
sales_data.describe(include=['O'])
# Out:
#               ORDERDATE   STATUS   PRODUCTLINE PRODUCTCODE  \
# count              2823     2823          2823        2823
# unique              252        6             7         109
# top     11/14/2003 0:00  Shipped  Classic Cars    S18_3232
# freq                 38     2617           967          52
#
#                  CUSTOMERNAME           PHONE        ADDRESSLINE1  \
# count                    2823            2823                2823
# unique                     92              91                  92
# top     Euro Shopping Channel  (91) 555 94 44  C/ Moralzarzal, 86
# freq                      259             259                 259
#
#        ADDRESSLINE2    CITY STATE POSTALCODE COUNTRY TERRITORY  \
# count           302    2823  1337       2747    2823      1749
# unique            9      73    16         73      19         3
# top         Level 3  Madrid    CA      28034     USA      EMEA
# freq             55     304   416        259    1004      1407
#
# ...

# %%
sales_data.isnull().sum()
# Out:
# ORDERNUMBER            0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# PHONE                  0
# ADDRESSLINE1           0
# ADDRESSLINE2        2521
# CITY                   0
# STATE               1486
# POSTALCODE            76
# COUNTRY                0
# TERRITORY           1074
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %%
sales_data.isna().sum()
# Out:
# ORDERNUMBER            0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# PHONE                  0
# ADDRESSLINE1           0
# ADDRESSLINE2        2521
# CITY                   0
# STATE               1486
# POSTALCODE            76
# COUNTRY                0
# TERRITORY           1074
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %%
sales_data.TERRITORY.unique()
# Out:
# array([nan, 'EMEA', 'APAC', 'Japan'], dtype=object)

# %%
sales_data.COUNTRY.unique()
# Out:
# array(['USA', 'France', 'Norway', 'Australia', 'Finland', 'Austria', 'UK',
#        'Spain', 'Sweden', 'Singapore', 'Canada', 'Japan', 'Italy',
#        'Denmark', 'Belgium', 'Philippines', 'Germany', 'Switzerland',
#        'Ireland'], dtype=object)

# %%
sales_data.loc[sales_data['COUNTRY']=='USA']
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# 5           10168               36      96.66                1  3479.76
# 8           10201               22      98.57                2  2168.54
# ...           ...              ...        ...              ...      ...
# 2804        10185               28      64.43                6  1804.04
# 2807        10222               36      63.34               18  2280.24
# 2809        10248               23      65.52                9  1506.96
# 2817        10337               42      97.16                5  4080.72
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE     STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
sales_data['TERRITORY']=sales_data['TERRITORY'].fillna('Americas')

# %%
#find all instances where territory is null and assign to variable
 
null_t = sales_data.loc[sales_data['TERRITORY'].isnull()]
 
#find impacted countries from null list
 
null_t.COUNTRY.unique()
# Out:
# array([], dtype=object)

# %%
sales_data['TERRITORY']=sales_data['TERRITORY'].replace('Japan', 'APAC')

# %%
sales_data.TERRITORY.unique()
# Out:
# array(['Americas', 'EMEA', 'APAC'], dtype=object)

# %% [markdown]
# # 3. EDA

# %%
sales_data.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE',
#        'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE',
#        'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME',
#        'DEALSIZE'],
#       dtype='object')

# %%
sales_data.TERRITORY.hist()
# Out:
# <Axes: >

# %%
plt.style.use('_mpl-gallery')
 
# plot:
#plt.figure(figsize=(10,6))
fig, ax = plt.subplots(figsize=(10,6))
 
ax.hist(sales_data['COUNTRY'], bins=15, linewidth=0.5, edgecolor="white")
 
ax.set(xticks=sales_data['COUNTRY'])
 
plt.show()

# %%
# Plotting the Sales distribution
plt.figure(figsize=(10, 6))
plt.hist(sales_data['SALES'], bins=20, color='skyblue', edgecolor='black')
plt.xlabel('Sales')
plt.ylabel('Frequency')
plt.title('Distribution of Sales Amounts')
plt.show()

# %%
# Set the style 

sns.set_theme(style="darkgrid")
 
# Create figure and axis

fig, ax = plt.subplots(figsize=(12,6))
 
#create the histogram

sns.histplot(data=sales_data, x='COUNTRY', stat='count', discrete=True,kde=False, ax=ax, palette='viridis')
 
# Customize the plot

ax.set_title('Distribution of Country in the dataset', fontsize=16)

ax.set_xlabel('Country', fontsize=12)

ax.set_ylabel('Count', fontsize=12)
 
# Rotate x-axis labels for better readability

plt.xticks(rotation=45, ha='right')
 
# Adjust layout to prevent cutting off labels

plt.tight_layout()
 
# Show the plot

plt.show()
# Out:
# /tmp/ipykernel_33/937873449.py:11: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data=sales_data, x='COUNTRY', stat='count', discrete=True,kde=False, ax=ax, palette='viridis')
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Set the style 

sns.set_theme(style="darkgrid")
 
# Create figure and axis

fig, ax = plt.subplots(figsize=(12,6))
 
#create the histogram

sns.barplot(data=sales_data, x='COUNTRY', y='SALES', ax=ax, palette='viridis')
 
# Customize the plot

ax.set_title('Sales by country', fontsize=16)

ax.set_xlabel('Country', fontsize=12)

ax.set_ylabel('Sales', fontsize=12)
 
# Rotate x-axis labels for better readability

plt.xticks(rotation=45, ha='right')
 
# Adjust layout to prevent cutting off labels

plt.tight_layout()
 
# Show the plot

plt.show()

# %%
# Set the style
sns.set_theme(style="darkgrid")
 
# Create figure and axis
fig, ax = plt.subplots(figsize=(12,6))
 
#create the histogram
sns.barplot(data=sales_data, x='COUNTRY', y='SALES', ax=ax, palette='viridis')
 
# Customize the plot
ax.set_title('Sales by country', fontsize=16)
ax.set_xlabel('Country', fontsize=12)
ax.set_ylabel('Sales', fontsize=12)
 
# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')
 
# Adjust layout to prevent cutting off labels
plt.tight_layout()
 
# Show the plot
plt.show()

# %% [markdown]
# # What are the total sales over the past year?

# %%
#- What are the total sales over the past year?

SalesPerYear = sales_data.groupby('YEAR_ID')['SALES'].sum().reset_index()
SalesPerYear.head()
# Out:
#    YEAR_ID        SALES
# 0     2003  3516.979540
# 1     2004  3512.388550
# 2     2005  3747.880146

# %%
sns.barplot(data=SalesPerYear, y='SALES', x='YEAR_ID')
plt.title('Sales Per Year')
# Out:
# Text(0.5, 1.0, 'Sales Per Year')

# %%
# Set the style 

sns.set_theme(style="darkgrid")
 
# Create figure and axis

sns.lineplot(data=SalesPerYear.head(20), x='YEAR_ID', y='SALES', palette='viridis')

plt.tight_layout()
 
# Show the plot

plt.show()
# Out:
# /tmp/ipykernel_33/3021541647.py:7: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data=SalesPerYear.head(20), x='YEAR_ID', y='SALES', palette='viridis')
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # What are the peak sales months?

# %% [markdown]
# Tee can you check this code i did peak sales month but i think ive done something wrong
#
# SalesPerMonth = sales_data.groupby('MONTH_ID')['SALES'].sum().reset_index()
#
# sns.set_theme(style="darkgrid")
#
#
#
# sns.barplot(data=SalesPerMonth, y='SALES', x='MONTH_ID', palette='coolwarm')
#
#
#
# plt.title('sales per months')

# %%
SalesPerMonth = sales_data.groupby('MONTH_ID')['SALES'].sum().reset_index()
                                             
sns.set_theme(style="darkgrid")

sns.barplot(data=SalesPerMonth, y='SALES', x='MONTH_ID', palette='coolwarm')

plt.title('sales per months')
# Out:
# Text(0.5, 1.0, 'sales per months')

# %%
unique_months = sales_data['MONTH_ID'].unique()
temp=pd.DataFrame()
# Create subplots for each year
for i, month in enumerate(unique_months):
    month_data = sales_data[sales_data['MONTH_ID'] == month]
    month_data=month_data.groupby('YEAR_ID')['SALES'].sum().reset_index()
    month_data['MONTH_ID'] = month
        temp = pd.concat([temp,month_data], ignore_index=True)

plt.figure(figsize=(20,8))
plt.title("Month Revenue by Year") # add title 
a= sns.barplot(x='MONTH_ID',y='SALES',data=temp,hue='YEAR_ID')
plt.xticks()

plt.show()

# %% [markdown]
# # Which product has the highest sales?

# %%
# Which product has the highest sales?

sales_data.PRODUCTLINE.unique()
# Out:
# array(['Motorcycles', 'Classic Cars', 'Trucks and Buses', 'Vintage Cars',
#        'Planes', 'Ships', 'Trains'], dtype=object)

# %%
ProductSales = pd.DataFrame(sales_data.groupby('PRODUCTLINE')['SALES'].sum()).reset_index()

ProductSalesSorted = ProductSales.sort_values(by='SALES')
 
ProductSales
# Out:
#         PRODUCTLINE       SALES
# 0      Classic Cars  3919615.66
# 1       Motorcycles  1166388.34
# 2            Planes   975003.57
# 3             Ships   714437.13
# 4            Trains   226243.47
# 5  Trucks and Buses  1127789.84
# 6      Vintage Cars  1903150.84

# %%
sns.barplot(data=ProductSalesSorted, x='PRODUCTLINE', y='SALES', palette='viridis')
plt.title('Which Product Was More Demandable')
plt.ylabel('Quantity')
plt.xlabel('Products')
plt.xticks(rotation=45, size=10)
plt.show()

# %%
DemandableProductPerYear = sales_data['PRODUCTLINE'].unique()
temp=pd.DataFrame()

for i, product in enumerate(DemandableProductPerYear):
    productdata = sales_data[sales_data['PRODUCTLINE'] == product]
    productdata = productdata.groupby('YEAR_ID')['SALES'].sum().reset_index()
    productdata['PRODUCTLINE'] = product
    temp = pd.concat([temp,productdata], ignore_index=True)
    
plt.figure(figsize=(20,10))
plt.title("Which Product Was More Demandable by Year")
a= sns.barplot(x='PRODUCTLINE',y='SALES',data=temp,hue='YEAR_ID')
plt.xticks()
plt.show()

# %%
# Set the style 
sns.set_theme(style="darkgrid")
 
# Create figure and axis
fig, ax = plt.subplots(figsize=(12,6))
 
#create the histogram
sns.barplot(data=product_sales_sorted, x='PRODUCTLINE', y='SALES', ax=ax, palette='viridis')
 
# Customize the plot
ax.set_title('Sales by category', fontsize=16)
ax.set_xlabel('Country', fontsize=12)
ax.set_ylabel('Sales', fontsize=12)
 
# Rotate x-axis labels for better readability
plt.xticks(rotation=0, ha='center')
 
# Adjust layout to prevent cutting off labels
plt.tight_layout()
 
# Show the plot
plt.show()

# %%
ProductSales2 = sales_data['PRODUCTLINE'][sales_data['YEAR_ID'] == 2004].value_counts().reset_index()
ProductSales2.head()
# Out:
#         PRODUCTLINE  count
# 0      Classic Cars    442
# 1      Vintage Cars    284
# 2       Motorcycles    164
# 3            Planes    161
# 4  Trucks and Buses    142

# %% [markdown]
# # Average Sales

# %%
AvgSales=sales_data["SALES"].mean()
AvgSales
# Out:
# 3553.889071909316

# %%
OrderIdSales = pd.DataFrame (sales_data.groupby('ORDERNUMBER')['SALES'].mean().reset_index())
OrderIdSales
# Out:
#      ORDERNUMBER        SALES
# 0          10100  3033.312500
# 1          10101  2858.085000
# 2          10102  3432.025000
# 3          10103  3418.875000
# 4          10104  3432.458462
# ..           ...          ...
# 302        10421  3630.875000
# 303        10422  3083.400000
# 304        10423  1682.390000
# 305        10424  5855.556667
# 306        10425  3368.053077
#
# [307 rows x 2 columns]

# %%
# Set the style 

sns.set_theme(style="darkgrid")
 
# Create figure and axis

fig, ax = plt.subplots(figsize=(12,6))
 
#create the histogram

sns.lineplot(data=OrderIdSales.head(20), x='ORDERNUMBER', y='SALES', ax=ax, palette='viridis')
 
# Customize the plot

ax.set_title('Sales by order number', fontsize=16)

ax.set_xlabel('order number', fontsize=12)

ax.set_ylabel('Sales', fontsize=12)
 
# Rotate x-axis labels for better readability

plt.xticks(rotation=0, ha='center')
 
# Adjust layout to prevent cutting off labels

plt.tight_layout()
 
# Show the plot

plt.show()
# Out:
# /tmp/ipykernel_33/3092603332.py:11: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data=OrderIdSales.head(20), x='ORDERNUMBER', y='SALES', ax=ax, palette='viridis')
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # Uuniques customers

# %%
sales_data['CUSTOMERNAME'].nunique()
# Out:
# 92

# %%
Sales2004 = sales_data.loc[sales_data['YEAR_ID']==2004]
Sales2003 = sales_data.loc[sales_data['YEAR_ID']==2003]
Sales2005 = sales_data.loc[sales_data['YEAR_ID']==2005]

# %%
MonthlySales2004 = pd.DataFrame(Sales2004.groupby('MONTH_ID')['SALES'].sum()).reset_index()
MonthlySales2004
# Out:
#     MONTH_ID       SALES
# 0          1   316577.42
# 1          2   311419.53
# 2          3   205733.73
# 3          4   206148.12
# 4          5   273438.39
# 5          6   286674.22
# 6          7   327144.09
# 7          8   461501.27
# 8          9   320750.91
# 9         10   552924.25
# 10        11  1089048.01
# 11        12   372802.66

# %%
# Set the style 

sns.set_theme(style="darkgrid")
 
# Create figure and axis

fig, ax = plt.subplots(figsize=(12,6))
 
#create the histogram

sns.barplot(data=MonthlySales2004, x='MONTH_ID', y='SALES', ax=ax, palette='viridis')
 
# Customize the plot

ax.set_title('Sales by month id in 2004', fontsize=16)

ax.set_xlabel('month id', fontsize=12)

ax.set_ylabel('Sales', fontsize=12)
 
# Rotate x-axis labels for better readability

plt.xticks(rotation=0, ha='center')
 
# Adjust layout to prevent cutting off labels

plt.tight_layout()
 
# Show the plot

plt.show()

# %%
RegionSales2005 = pd.DataFrame(Sales2005.groupby('TERRITORY')['SALES'].sum()).reset_index()
RegionSales2005.sort_values(by='SALES')
# Out:
#   TERRITORY      SALES
# 0      APAC  190600.49
# 1  Americas  671057.23
# 2      EMEA  929828.99

# %%
RegionRevenuePerYear = sales_data['TERRITORY'].unique()
temp=pd.DataFrame()

for i, territory in enumerate(RegionRevenuePerYear):
    territorydata = sales_data[sales_data['TERRITORY'] == territory]
    territorydata = territorydata.groupby('YEAR_ID')['SALES'].sum().reset_index()
    territorydata['TERRITORY'] = territory
    temp = pd.concat([temp,territorydata], ignore_index=True)
    
plt.figure(figsize=(20,10))
plt.title("Region Revenue by Year")
a= sns.barplot(x='TERRITORY',y='SALES',data=temp,hue='YEAR_ID')
plt.xticks()
plt.show()

# %%
CountryRevenuePerYear = sales_data['COUNTRY'].unique()
temp=pd.DataFrame()

for i, country in enumerate(CountryRevenuePerYear):
    country_data = sales_data[sales_data['COUNTRY'] == country]
    country_data=country_data.groupby('YEAR_ID')['SALES'].sum().reset_index()
    country_data['COUNTRY'] = country
    temp = pd.concat([temp,country_data], ignore_index=True)
    
plt.figure(figsize=(20,10))
plt.title("Country Revenue by Year")
a= sns.barplot(x='COUNTRY',y='SALES',data=temp,hue='YEAR_ID')
plt.xticks()
plt.show()

# %% [markdown]
# # pivot table

# %%
PivotYearlySales = sales_data.pivot_table(

                    values='SALES',

                    index='TERRITORY',

                    columns = 'YEAR_ID',

                    aggfunc='sum')

PivotYearlySales
# Out:
# YEAR_ID          2003        2004       2005
# TERRITORY
# APAC        496907.63   513786.93  190600.49
# Americas   1359757.38  1821246.78  671057.23
# EMEA       1660314.53  2389128.89  929828.99

# %%
PivotYearlySales1 = PivotYearlySales.reset_index()

PivotYearlySales1
# Out:
# YEAR_ID TERRITORY        2003        2004       2005
# 0            APAC   496907.63   513786.93  190600.49
# 1        Americas  1359757.38  1821246.78  671057.23
# 2            EMEA  1660314.53  2389128.89  929828.99

# %%
PivotYearlySales.plot()
# Out:
# <Axes: xlabel='TERRITORY'>

# %%
PivotYearlySales.plot(kind='bar', figsize=(10,6))

plt.title('Sales of Product by Year')

plt.xlabel('Territory')

plt.ylabel('Total Sales')

plt.legend(title='Territory vs Sales')

plt.xticks(rotation=0, ha='center')

plt.show()

# %%
PivotYearlySales2 = sales_data.pivot_table(

                    values='SALES',

                    index='TERRITORY',

                    columns = 'YEAR_ID',

                    aggfunc=['sum', 'mean', 'max', 'min'])

PivotYearlySales2
# Out:
#                   sum                                mean               \
# YEAR_ID          2003        2004       2005         2003         2004
# TERRITORY
# APAC        496907.63   513786.93  190600.49  3549.340214  3519.088562
# Americas   1359757.38  1821246.78  671057.23  3559.574293  3502.397654
# EMEA       1660314.53  2389128.89  929828.99  3473.461360  3518.599249
#
#                             max                        min
# YEAR_ID           2005     2003     2004      2005    2003     2004    2005
# TERRITORY
# APAC       3403.580179  10993.5  10758.0   8470.14  759.46  1030.44  553.95
# Americas   3901.495523  11279.2  12536.5  14082.80  717.40   651.80  541.14
# EMEA       3719.315960   8892.9  10606.2  12001.00  710.20   577.60  482.13

# %%
PivotYearlySales2['sum'].plot(kind='bar', figsize=(10,6))

plt.title('Mean Sales of Product by Year')

plt.xlabel('Territory')

plt.ylabel('Total Sales')

plt.legend(title='Territory vs Sales')

plt.xticks(rotation=0, ha='center')

plt.show()
